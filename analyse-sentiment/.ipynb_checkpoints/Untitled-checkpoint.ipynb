# %%
import re
import csv
import pandas as pd
import numpy as np
from typing import Pattern

from textblob.classifiers import NaiveBayesClassifier
import nltk 
from nltk.stem.snowball import FrenchStemmer 
from nltk.corpus import stopwords 

from sklearn.preprocessing import LabelEncoder

# %%
path_init = "data/_57793TransmissionsSurvivors_2014V1.2.csv"
path_train = 'data/TransmissionsSurvivors_2014V1.100-sentiments.csv'
path_new_sentiments = "data/no-clean-text-sentiments.csv"

PATTERN_SUPP_HTML : Pattern = re.compile(r'<(.*?)>')
REPLACE_NO_SPACE : Pattern = re.compile(r"[.;:!=\%?,\"()\[\]]")
REPLACE_WITH_SPACE : Pattern = re.compile(r"(<br\s*/><br\s*/>)|(\-)|(\/)|°")

# %%
data = pd.read_csv(path_train, sep=";")
data.head(10)
# Out:
#    id_resident  id_etablissement      date_T  \
# 0          166               207  1416984022
# 1          166               207  1416984022
# 2          166               207  1417034650
# 3          166               207  1417105358
# 4          166               207  1418539640
# 5          166               207  1418539640
# 6          166               207  1418580076
# 7          166               207  1419517509
# 8          166               207  1419851210
# 9          166               207  1419863156
#
#                                         descriptions sentiments
# 0                         je n'ai pas vu le pilulier   Negative
# 1                                      ttt non donné   Negative
# 2  j'ai retrouvé mR en train de pleurer ce soir ,...   Negative
# 3  Dr Traolen est contacté aujourd'hui pour renou...   Negative
# 4  les filles lui ont donné le laxatif ( supposit...   Negative
# 5                                         selles +++   Negative
# 6  Remis à Patricia fille de M.PRINCE ce jour les...   Positive
# 7  Mr Prince me qu'il a trés mal au dent il n'a p...   Negative
# 8  Monsieur n'ayant pas eu de selles pendant troi...   Negative
# 9            Absence de selle depuis plus de 3 jorus   Negative

# %%
# nettoyer le texte 
def preprocess_clean(reviews):
	reviews = reviews.lower() # mettre le texte en minuscule

	reviews = re.sub(r'\bagrave\b', 'a', reviews) #replacer agrave par a (!à)
	reviews = re.sub(r'\beacut\b|\begrave\b|\bpreacute\b', 'e', reviews)#

	sub_html = re.findall(PATTERN_SUPP_HTML, reviews) #supprimer les balise html
	for html in sub_html:
		if html:
			reviews = re.sub(r'\s+', ' ', reviews)
			reviews = re.sub(r"\'", ' ', reviews)
			reviews = reviews.replace(html, '')
			reviews = reviews.replace('<>', ' ')

	reviews = REPLACE_NO_SPACE.sub(' ', reviews) #supprimer tout les caracteres [.;:!=\%?,\"()\[\]]
	reviews = REPLACE_WITH_SPACE.sub(' ', reviews) #supprimer espace entre balise html au cas où y'en a 
	reviews = reviews.replace('ttt', 'traitement') 
	# reviews = re.sub(r"([+])", ' plus ', reviews)
	reviews = re.sub(r"([+])", ' ', reviews)
	reviews = re.sub(r'[0-9]', '', reviews)

	reviews = re.sub(' +', ' ', reviews)#supprimer tout espace de plus qui peut exister à la fin de traitement

	return reviews

# %%
for i, descr in enumerate(data['descriptions']):
    descr = preprocess_clean(descr)
    print(data.loc[i])
    #print(descr)#
# Out:
# je n'ai pas vu le pilulier
# traitement non donné
# j'ai retrouvé mr en train de pleurer ce soir il m'informe la mort de sa femme à l'hopital pompidou
# dr traolen est contacté aujourd'hui pour renouveller le stilnox de mr prince il a faxé une ordonnance de stilnox pour un mois l'ordonnance est faxé à la pharmacie cet aprés midi
# les filles lui ont donné le laxatif suppositoire
# selles
# remis à patricia fille de m prince ce jour les € que salomé avait laissé dans le coffre
# mr prince me qu'il a trés mal au dent il n'a pas mangé son plat a midi i d e prévenue
# monsieur n'ayant pas eu de selles pendant trois jours a eu un lavement par l'infirmier avant la toilette intime monsieur a fait des selles n
# absence de selle depuis plus de jorus
# lavement par normacol fait ce matin
# le résident a eu des selles en fin de matinée selon les dires de la soingnantes
# il dit qu'il a mal a la dent
# mme etait perturber ce matin par rapport qu'on lui est voler de l'argent
# mme a son chequier dans le tiroir de sa commande je lui ai dit sa serai mieux de le mettre au coffre elle a refuser
# a fait sa toilette seule ce matin aide pour les bas de contention
# douloureuse au pouce pied gauche
# medtrait appelé pour ro passera jeudi dans la journée
# mme a preferer mettre ses bas de contention au lieu de ses collants de contention
# mme me dit qu'elle veut plus de ses collant en cottention veut revenir au bas de contention donc a voir
# mme sonne a h pour me dire qu'elle a mal a l'estomac et partout pris tension a pulsation a o j'ai essayé d'appeler l'ide pour lui dire mme a resonné ma collegue et partir la voir et a eu l'ide au telephone
# douloureuse au niveau des jambes
# prevenir l'ide
# douleur au talons
# mme b est toujours douloureuse au niveau des jambes et des talons
# mme etait mecontente car on lui a changer la taille de protection dit que la taille m est trop petite pour elle je lui ai dit que je verrai avec la cadre
# programme au objectifs poirier morgane psychomotricienne h se sentir en sécurité face à son incontinence nocturneactions poirier morgane psychomotricienne h a la demande de la résidente ajouter une anaform en plus dans la pull upsressources poirier morgane psychomotricienne h responsable soignants gouvernante idecindicateur nuitsuivi plan de soinévaluation poirier morgane psychomotricienne h selon le souhait de la résidente accordé par l'idec et la gouvernante
# mme a manger avec sa fille ce h
# mme a refuser de prendre le gouter
# a eu son vaccin antigrippal immugrip lot n mx le à h
# mme a des boutons rouges sur l'epaule et le dos
# merci de programmé la douche de mme c chaque mercredi au plus tard avant h selon son souhait
# mme a refusé de prendre sa douche ce matin
# mr de martini est levé et habillé depuis h du matin demande a partir de l'up
# faire moucherhydratée ide prevenu
# glaire retrouvé sur l'oreillé
# je lui expliquer de l'on etait samedi et que les banques etaient fermés et qu'ils le seront aussi le lendemain ide perevenu surveillance
# veut sortir de l'up pour aller a la banque fois de suite le samedi et le dimannche
# mme demartini veut sortir pour aller a la banque
# mme demartini va bien j'ai pris des rasoirs car n'ont avait plus mousse a raser il a eu un chocolat donner par idec pour le devier de ses envies de sortie a l'exterieur
# mme demartini va bien a passe une bonne journee il etait u peu retissant quand je lui propose la douche mais a fini par accepte
# monsieur de martin a passer une nuit tres calme
# il a pris ses marques s'oriente bien dans l'unité protégée et il se sent chez lui celui ci communique bien avec les soignants dans l'ensemble tout se passe très bien ainsi qu'au moment de la toilette
# cela fait quelques jour que mr demartini ne demande plus a laller a la banque
# une barre chocolaté lui ai donne par jour mise en place par idec
# va mieux
# retour a la normal du transit
# mme demartini est sortie pour l'activité marché de noel et il a acheté pour euro de gateau avec de largent qu'il avait dans son porte monai
# draps souillé douche faite ainsi que change de draps
# mr de martini tousse depuis h du matin prévenir ide
# geacute neacute ration du dossier de liaison d'urgencefamille e venue non
# fatigué il a du mal à se mouvoir je lui ai fait une toilette au lit
# toux signalée ce matin avec une température à ta pouls à dafalgan g donné dans la journée avec surveillance de la température suite à la recommandation de l'idec tousse moins dans l'après midi avec une température à laxatif donné car difficulté à aller à la selle selon l'as
# priere d'assurer une bonne hydratation
# a mon arrivée ce matin je l'ai trouvé aux toilettes puis il s'est rendu au salon pour le petit déjeuner fatigué il n'a pris que le il tousse
# pas de selle depuis hier laxatif donnè
# il a essayé de se déplacer de reprendre ses habitudes mais il est gêné il ne répond pas aux questions posées quant à la douleur après le dîner fatigué il se penchait à gauche je l'ai accompagné en chambre il s'est endormi tout de suite
# il se plaint d'avoir mal au ventre et puis sur sa poitrine il dit d'être essoufflé à l'effort
# avant le déjeuner il devait se tordre de douleur au ventre et après minutes ça allée bien et elle a finit son assiette par contre il est resté dans la salle à manger entrain de somnolé sur sa chaise
# surveillance
# il a eu la visite de sa soeur ainsi que sa niece a la demande de sa soeur rvd pris chez la coiffeuse pour mardi janvier à h
# il a beauoup toussé cet après midi
# madame avait ses bas de contention avant de prendre le petit déjeuner puique je les ai mis la stagiaire célia s'est aperçue que madame ne les avait plussur les jambes elle lui a remis
# a voir si il serait possible d'améliorer le chaussage de mme delabre bottine qui prend la cheville en vu d'apporter une petite correction orthopédique sur le pied gauche qui est très en equin ou au moins de le stabiliser pour éviter l'aggravation
# mme d toujours contente
# madame très contrariée ce soir voulait sortir de table je lui en n'ai demandé la raison elle avait reçu un coup de fil lui annonçant que sa maisonse détériorait je l'ai rassuré elle ne m'a pas donné le nom de la personne elle était trop affolé je lui ai dit qu'elle finisse son repas qu'elle se reposeet que l'on n'en discuterait demain matin elle en n'était soulagée et a fini son repas et m'en a remercié
# très enervée pendant ma ronde dit que je suis passé plus tard que d'habitude je lui ai fait comprendre que c'est ma première nuit et que cela prend plus de temps que d'habitude
# pour me delgado seconde nuit également avec la protection anatomique la nuit dernière s'est palinte du slip filet elle disait ressentir une gêne avec celle ci mais après négociation avit quand même acceptée de la garder durant la nuit pour cette nuit tjrs la protection anatomique mais sans le slip filet essaie positif à mieux accepter au niveau de la protection anatomique pas de souci celle ci est correctement restée en place pas de fuite
# mr boetto est rentré dans la chambre de mme delgado ce matin il lui a donner un coup de canne au niveau du crane qui a engendrer une bosse un hematome frontale poche de glace mise sur place famille non prévenu suite a cet incident mme d souhaite avoir une clef pour fermer sa chambre
# aujourd'hui dans le grand salon elle passait son temps a dire salaud imbecile et merde aux autres résidents sinon ce matin elle s'est levé du mauvais pied très énervé et elle ne s'est pas énervée au moment du répas car elle était calme contrairement a ce matin cet après midi elle m'a dit je ne sais pas ce que j'ai depuis quelque temps
# refus de se mettre en chemise de nuit ce soir elle est énervé
# mme duhem est très énervée se soir a accepté de se coucher vers h coucher difficile
#  mme duhem est très énervée se soir a accepté de se coucher vers h coucher difficile
# elle est toujours énervé et elle n'arrête pas d'insulté les autres résidents agressive au moment du répas celle ci avait renversé son assiette par terre et elle s'est mise à crié dans le grand salon je l'accompagné donc dans sa chambre et lui dit de faire une petite sieste elle commencé à dire non en criant fort je l'ai installé sur une chaise dans sa chambre et après elle était bien calme et elle à mangé que son entrée
# agitée après ma pause son fils est venu me demande de changer la proctetion de sa maman qui était tremper dans ses urines mme duhem très désagréable elle à refusé et après négociation elle finie par accepté son fils était bien content car sa maman se calmer enfin
# mme duhem va beaucoup mieux aujourd'hui n'hurle plus
# mme duhem refusé le change et l'accompagnement au toilette j'ai eu des difficultés pour sa toilette le matin et ce soir elle refuese de se mettre en chemise de nuit agitéé
# mme duhem très agitée cet après midi elle est retourné faire une petite sieste dans sa chambre par contre elle a mangé en chambre ce soir car elle n'a pas voulu sortir de sa chambre et elle a préféré dîner dans sa chambre
# mme duhem a eut des difficultées respiratoires se matin je l'ai mise en position assise et la crise a fini par passer au bout de minutes elle a reussit a se rendormir
# une journée calme cet après midi elle est resté dans sa chambre pour faire la lecture
# mme duhem agitéé a hurle toute la journeé a frappe mr brem car ce dernier etait sur son lit
# madame duhem ce matin dit vouloir envie de vomir
# calme ce matin au moment de la toilette par contre cet après midi elle était très énervé
# agitée ce jour refus de s'alimenter ce midi elle dit avoir un manque de goût de vivre
# refus de se mettre en chemise nuit elle est resté dans le grand salon
# geacute neacute ration du dossier de liaison d'urgencefamille e venue non
# le fils de mme duhem a été informé du transfert aux urgences par téléphone il sera absent de ce jour à dimanche inclus en cas d'urgence le prévenir sur son portable
# douleur thoracique dyspnée oedèmes des mi ta mmhg pbpm spo aa t cvu par medco transfert aux urgences de l'hôpital st camille fils prevenue par téléphone
# appel à l'hôpital st camille pour prendre des nouvelles de la résidante me d a été transferée ce matin à l'hôpital emile roux éme g confirmation d' épanchement pleural à gch très agitée refuse les soins fils prevenu
# chambre faite à blanc le rideaux enlevés le
# mme duhem rentreras demain aprés midi d'hospi
# mme d retour d'hospitalisation
# pese observation de l'etata cutané bon pas de rougeures ni hematomestransit a fait des selles m a son retour
# madame duhem a etait tres agiter cette nuit et agressif
# rapport médical d'hospitalisation transmis au mt ce jour
# elle est bien portante ce jour et elle mange ses repas
# refus de perfusion
# mme duhem est très agitée se soir causé par l'agressivité de mr capelli
# agitée refus de se mettre en chemise de nuit
# mme duhem était agitée a mon arrivé pas de souci au moment de la mettre au lit
# toujours très expressive mme est de très bonne humeur elle tousse se fatigue à la toilette transmis à ide
# mme signale une douleur au niveau du bas ventre eva
# mal dormie acause de mme miranda qui diambule ds le couloir et rentre ds les chambres
# prochaine visite du médecin traitant dr formaglio le décembre
# mme fourny m'a remit hier une ordonnance pour une panoramique dentaire demandé par le docteur lelluch jennifer mais on appelant les differents centre d'imagerie hier aucun ne fait ce type de radiographie chez une personne qui ne se tient pas debout fille informé vu avec médecin co qui me demande de revoir avec le dentiste afin qu'il nous fait une prescription de defile maxillaire au lieu de la panoramique dentaire j'ai appeler le dentiste hier apres midi pour lui demandé s'il etait possible de nous changer l'ordonnance avec la nouvelle prescription et la secretaire m'a dit qu'elle allait nous la faxée hier aprés midi mais on a reçu je l'ai rappelé ce matin et selon ses dires le docteur a oublier de la faire et elle va nous la faxée le lundi
# mme f ce matin elle a eu mal partout
# le dentiste rappeler ce jour pour qu'il nous fax l'ordonnance de défilé maxilaire au lieu du panoramique dentaire ordonnance reçu vers h rdv pris demain le au centre d'imagerie de gagny à h depart par ambulance vers h fille prevenue
# la résidente a eu sa radiographie defile maxilaire ce jour par contre pas de rdv pris avec le dentiste car quand j'ai appelé la résidente pour voir ses disponibilités elle me dit qu'elle ne sais rien du tout et qu'elle verra ça la semaine prochaine
# douloureur au dos
# douleurs aux hanches plutot
# madame a perdu ses lunettes hier matin et me dit qu'elle ne les avait pas depuis cette date c'est à dire le au matin je suis allée à la lingeriece matin pour savoir si elles étaient dans les sacs elis d'hier je n'ai rien trouvé j'en n'ai informé la résidente elle m'a dit qu'elle avait informésa fille aînée de la perte de ses lunettes depuis hier dans la journée
# l'agent d'entretien jania m'a dit qu'elle avait retrouvé les lunettes de madame fourny dans la salle de bain près de sa cuvette
# monsieur becot sait levé vers h pour me demande ou il etait ce qu'il faisait ici depuis combien de temps iln etait ici lui meme a ma dis qu'il perdait la tete il etait completement desorienté perturbé je l'ai ramener a ca change je l'ai calmé et expliquer les choses et je l'ai recoucher

# %%
data = data.sample(frac=1).reset_index(drop=True)

# %%
def get_stopswords(type="veronis"):
    '''Suppression des mots vides avec NLTK'''
    if type == "veronis":

        raw_stopword_list = ["Ap.", "Apr.", "GHz", "MHz", "USD", "a", "afin", "ah", "ai", "aie", "aient","aies", 
                             "ait", "alors", "après", "as", "attendu", "au", "au-delà", "au-devant","aucun", 
                             "aucune", "audit", "auprès", "auquel", "aura", "aurai", "auraient","aurais", 
                             "aurait", "auras", "aurez", "auriez", "aurions", "aurons", "auront", "aussi", 
                             "autour", "autre", "autres", "autrui", "aux", "auxdites", "auxdits", "auxquelles", 
                             "auxquels", "avaient", "avais", "avait", "avant", "avec", "avez", "aviez", 
                             "avions", "avons", "ayant", "ayez", "ayons", "b", "bah", "banco", "ben","bien", 
                             "bé", "c", "c'", "c'est", "c'était", "car", "ce", "ceci", "cela", "celle",
                             "celle-ci", "celle-là", "celles", "celles-ci", "celles-là", "celui", "celui-ci",
                             "celui-là", "celà", "cent", "cents", "cependant", "certain", "certaine","certaines",
                             "certains", "ces", "cet", "cette", "ceux", "ceux-ci", "ceux-là","cf.", "cg", "cgr", 
                             "chacun", "chacune", "chaque", "chez", "ci", "cinq", "cinquante", "cinquante-cinq", 
                             "cinquante-deux", "cinquante-et-un","cinquante-huit", "cinquante-neuf", 
                             "cinquante-quatre", "cinquante-sept", "cinquante-six", "cinquante-trois", 
                             "cl", "cm", "cm²", "comme", "contre","d", "d'", "d'après", "d'un", "d'une", "dans", 
                             "de", "depuis", "derrière", "des", "desdites", "desdits", "desquelles", "desquels", 
                             "deux", "devant", "devers", "dg", "différentes", "différents", "divers", "diverses", "dix", 
                             "dix-huit", "dix-neuf", "dix-sept", "dl", "dm", "donc", "dont", "douze", "du", 
                             "dudit", "duquel", "durant", "dès", "déjà", "e", "eh", "elle", "elles","en", 
                             "en-dehors", "encore", "enfin", "entre", "envers", "es", "est", "et", "eu", "eue", 
                             "eues", "euh", "eurent", "eus", "eusse", "eussent", "eusses","eussiez", "eussions", 
                             "eut", "eux", "eûmes", "eût", "eûtes", "f", "fait", "fi", "flac", "fors", "furent", 
                             "fus", "fusse", "fussent", "fusses", "fussiez", "fussions", "fut", "fûmes", "fût", 
                             "fûtes", "g", "gr", "h", "ha", "han", "hein", "hem", "heu", "hg", "hl", "hm", "hm³", 
                             "holà", "hop", "hormis", "hors", "huit", "hum", "hé", "i", "ici", "il", "ils", "j", "j'", 
                             "j'ai", "j'avais", "j'étais","jamais", "je", "jusqu'", "jusqu'au", "jusqu'aux", "jusqu'à", 
                             "jusque", "k","kg", "km", "km²", "l", "l'", "l'autre", "l'on", "l'un", "l'une", "la", 
                             "laquelle", "le", "lequel", "les", "lesquelles", "lesquels", "leur", "leurs", "lez", 
                             "lors", "lorsqu'", "lorsque", "lui", "lès", "m", "m'", "ma", "maint", "mainte", 
                             "maintes", "maints", "mais", "malgré", "me", "mes", "mg", "mgr", "mil", "mille", 
                             "milliards", "millions", "ml", "mm", "mm²", "moi", "moins", "mon", "moyennant", "mt", 
                             "m²", "m³", "même", "mêmes", "n", "n'avait", "n'y", "ne", "neuf", "ni", "non", 
                             "nonante", "nonobstant", "nos", "notre", "nous", "nul", "nulle", "nº", "néanmoins", 
                             "o", "octante", "oh", "on", "ont", "onze", "or", "ou", "outre", "où", "p", "par", 
                             "par-delà", "parbleu", "parce", "parmi", "pas", "passé", "pendant", "personne", 
                             "peu", "plus", "plus_d'un", "plus_d'une", "plusieurs", "pour", "pourquoi", 
                             "pourtant", "pourvu", "près", "puisqu'", "puisque", "q", "qu", "qu'", "qu'elle",
                             "qu'elles", "qu'il", "qu'ils", "qu'on", "quand", "quant", "quarante", "quarante-cinq", 
                             "quarante-deux", "quarante-et-un", "quarante-huit", "quarante-neuf", "quarante-quatre", 
                             "quarante-sept", "quarante-six", "quarante-trois", "quatorze", "quatre", "quatre-vingt", 
                             "quatre-vingt-cinq", "quatre-vingt-deux", "quatre-vingt-dix", "quatre-vingt-dix-huit", 
                             "quatre-vingt-dix-neuf", "quatre-vingt-dix-sept", "quatre-vingt-douze", "quatre-vingt-huit", 
                             "quatre-vingt-neuf", "quatre-vingt-onze", "quatre-vingt-quatorze", "quatre-vingt-quatre", 
                             "quatre-vingt-quinze", "quatre-vingt-seize", "quatre-vingt-sept", "quatre-vingt-six", 
                             "quatre-vingt-treize", "quatre-vingt-trois", "quatre-vingt-un", "quatre-vingt-une", 
                             "quatre-vingts", "que", "quel", "quelle", "quelles", "quelqu'", "quelqu'un", 
                             "quelqu'une", "quelque", "quelques", "quelques-unes", "quelques-uns", "quels",
                             "qui", "quiconque", "quinze", "quoi", "quoiqu'", "quoique", "r", "revoici", 
                             "revoilà", "rien", "s", "s'", "sa", "sans", "sauf", "se", "seize", "selon", 
                             "sept", "septante", "sera", "serai", "seraient", "serais", "serait", "seras",
                             "serez", "seriez", "serions", "serons", "seront", "ses", "si", "sinon", "six", 
                             "soi", "soient", "sois", "soit", "soixante", "soixante-cinq", "soixante-deux", 
                             "soixante-dix", "soixante-dix-huit", "soixante-dix-neuf", "soixante-dix-sept", 
                             "soixante-douze", "soixante-et-onze", "soixante-et-un", "soixante-et-une", 
                             "soixante-huit", "soixante-neuf", "soixante-quatorze", "soixante-quatre", 
                             "soixante-quinze", "soixante-seize", "soixante-sept", "soixante-six", 
                             "soixante-treize", "soixante-trois", "sommes", "son", "sont", "sous", 
                             "soyez", "soyons", "suis", "suite", "sur", "sus", "t", "t'", "ta", 
                             "tacatac", "tandis", "te", "tel", "telle", "telles", "tels", "tes", 
                             "toi", "ton", "toujours", "tous", "tout", "toute", "toutefois", 
                             "toutes", "treize", "trente", "trente-cinq", "trente-deux", "trente-et-un",
                             "trente-huit", "trente-neuf", "trente-quatre", "trente-sept", "trente-six",
                             "trente-trois", "trois", "très", "tu", "u", "un", "une", "unes", "uns", "v", 
                             "vers", "via", "vingt", "vingt-cinq", "vingt-deux", "vingt-huit", "vingt-neuf", 
                             "vingt-quatre", "vingt-sept", "vingt-six", "vingt-trois", "vis-à-vis", "voici", 
                             "voilà", "vos", "votre", "vous", "w", "x", "y", "z", "zéro", "à", "ç'", "ça", 
                             "ès", "étaient", "étais", "était", "étant", "étiez", "étions", "été", "étée", 
                             "étées", "étés", "êtes", "être", "ô"]
    else:
        raw_stopword_list = stopwords.words('french')
        
    stopword_list = [word for word in raw_stopword_list] 
    return stopword_list

# %%
def filter_stopwords(text, stopword_list):
    # print(text)
    words = [w for w in text.split()] 
    filtered_words = [] 
    # print(words)
    for word in words: 
        if word not in stopword_list and word.isalpha() and len(word) > 1: 
            filtered_words.append(word) 
    filtered_words#.sort() 
    return filtered_words

# %%
#classifier les transmissions survivant 2014 
def Classifier_sentiment(path):
    global classifier
    with open(path, 'r') as csvfile:
        train_data, X_train, test_data = [], [], []

        for _,_,_,descriptions, sentiments in  csv.reader(csvfile, delimiter=';'):
            if descriptions:
                descriptions = preprocess_clean(descriptions)#clean text 
                stopword_list = get_stopswords()
                filtered_word = filter_stopwords(descriptions, stopword_list)
                # print(filtered_word)
                descriptions = ' '.join(filtered_word)
                data_tmp = descriptions, sentiments
                #print(descriptions) 
                train_data.append(data_tmp)

        #split le dataset en train et test 
        r = .0 
        for i in train_data:
            if r <= 8.5:
                X_train.append(i)
            else:
                test_data.append(i)

            r += .1

       # print(X_train)
        # #classifier avec NaiveBayesClassifier de package textblob
        classifier = NaiveBayesClassifier(X_train)
        print(classifier.accuracy(test_data))

# %%
Classifier_sentiment(path_train)
# Out:
# 0.6428571428571429

# %%
# Out:
#    id_resident  id_etablissement      date_T  \
# 0          166               207  1416984022
# 1          166               207  1416984022
# 2          166               207  1417034650
# 3          166               207  1417105358
# 4          166               207  1418539640
# 5          166               207  1418539640
# 6          166               207  1418580076
# 7          166               207  1419517509
#
#                                         descriptions sentiments
# 0                         je n'ai pas vu le pilulier   Negative
# 1                                      ttt non donné   Negative
# 2  j'ai retrouvé mR en train de pleurer ce soir ,...   Negative
# 3  Dr Traolen est contacté aujourd'hui pour renou...   Negative
# 4  les filles lui ont donné le laxatif ( supposit...   Negative
# 5                                         selles +++   Negative
# 6  Remis à Patricia fille de M.PRINCE ce jour les...   Positive
# 7  Mr Prince me qu'il a trés mal au dent il n'a p...   Negative

# %%
LE = LabelEncoder()
data['label_num'] = LE.fit_transform(data['sentiments'])
data = data[['descriptions','sentiments', 'label_num']]

# %%
# Out:
#                                          descriptions sentiments  label_num
# 0   Avant le déjeuner il devait se tordre de doule...   Negative          0
# 1                       glaire retrouvé sur l'oreillé   Negative          0
# 2                                      prevenir l'ide   Negative          0
# 3   Elle est bien portante ce jour, et elle mange ...   Positive          2
# 4   <span style="font-family: PT, Verdana, Arial, ...   Negative          0
# 5                                          selles +++   Negative          0
# 6               Mme F.ce matin elle a eu mal partout.   Negative          0
# 7    madame duhem ce matin dit vouloir envie de vomir   Negative          0
# 8   Monsieur n'ayant pas eu de selles pendant troi...   Negative          0
# 9   Mme sonne a 15h pour me dire qu'elle a mal a l...   Negative          0
# 10  Remis à Patricia fille de M.PRINCE ce jour les...   Positive          2
# 11                      retour a la normal du transit   Positive          2
# 12  le résident a eu des selles en fin de matinée ...   Negative          0
# 13  Mme duhem est très énervée se soir, a accepté ...   Negative          0
# 14  Mr boetto est rentré dans la chambre de Mme de...   Negative          0
# 15  Mme FOURNY m'a remit hier une ordonnance pour ...   Negative          0
# 16  pese:63.8observation de l'etata cutané:bon pas...   Positive          2
# 17  Geacute;neacute;ration du Dossier de liaison d...   Negative          0
# 18                                  douloureur au dos   Negative          0
# 19  Mme Duhem était agitée a mon arrivé, pas de so...   Negative          0
